# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      |████████████████████████████████| 13.1 MB 20.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/coder/.local/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      |████████████████████████████████| 345 kB 115.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.22.4 in /home/coder/.local/lib/python3.9/site-packages (from pandas) (2.0.0)
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      |████████████████████████████████| 505 kB 101.9 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: tzdata, pytz, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1

# %%
#Import the dataset and pandas
rom sklearn import datasets
import pandas as pd
 
# Load the diabetes datafset and create a dataframe
diabetes = datasets.load_diabetes()
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
 
# Add the target variable to the dataframe
df['target'] = diabetes.target
 
# Print the first 5 rows of some variables
print(df[['age', 'sex', 'bmi', 'target']].head())
# Out:
#         age       sex       bmi  target
# 0  0.038076  0.050680  0.061696   151.0
# 1 -0.001882 -0.044642 -0.051474    75.0
# 2  0.085299  0.050680  0.044451   141.0
# 3 -0.089063 -0.044642 -0.011595   206.0
# 4  0.005383 -0.044642 -0.036385   135.0

# %%
corr = df[['age', 'sex', 'bmi', 'target']].corr()
print(corr)
# Out:
#              age       sex       bmi    target
# age     1.000000  0.173737  0.185085  0.187889
# sex     0.173737  1.000000  0.088161  0.043062
# bmi     0.185085  0.088161  1.000000  0.586450
# target  0.187889  0.043062  0.586450  1.000000

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.40-py2.py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 3.4 MB/s  eta 0:00:01
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.4.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (116 kB)
#      |████████████████████████████████| 116 kB 32.9 MB/s eta 0:00:01
# Collecting lxml>=4.9.1
#   Downloading lxml-5.2.2-cp39-cp39-manylinux_2_28_x86_64.whl (5.0 MB)
#      |████████████████████████████████| 5.0 MB 109.3 MB/s eta 0:00:01
# Collecting peewee>=3.16.2
#   Downloading peewee-3.17.6.tar.gz (3.0 MB)
#      |████████████████████████████████| 3.0 MB 96.3 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: numpy>=1.16.5 in /home/coder/.local/lib/python3.9/site-packages (from yfinance) (2.0.0)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 90.9 MB/s eta 0:00:01
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 105.8 MB/s eta 0:00:01
# Requirement already satisfied: platformdirs>=2.0.0 in /home/coder/.local/lib/python3.9/site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /home/coder/.local/lib/python3.9/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: pandas>=1.3.0 in /home/coder/.local/lib/python3.9/site-packages (from yfinance) (2.2.2)
# Collecting requests>=2.31
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 6.0 MB/s  eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: six>=1.9 in /usr/lib/python3/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: tzdata>=2022.7 in /home/coder/.local/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/coder/.local/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Collecting idna<4,>=2.5
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 5.5 MB/s  eta 0:00:01
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 94.2 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 91.2 MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 91.2 MB/s eta 0:00:01
# Building wheels for collected packages: peewee
#   Building wheel for peewee (PEP 517) ... done
#   Created wheel for peewee: filename=peewee-3.17.6-cp39-cp39-linux_x86_64.whl size=757654 sha256=606bc111f31b222c1e0448da91eedb8838532308780b36ff35d4bcd075ff37c8
#   Stored in directory: /home/coder/.cache/pip/wheels/3e/23/b4/7729b2d48a34ee9d95c11f7f8dfd4ff0571a056e2691118b34
# Successfully built peewee
# Installing collected packages: webencodings, urllib3, soupsieve, idna, charset-normalizer, certifi, requests, peewee, multitasking, lxml, html5lib, frozendict, beautifulsoup4, yfinance
#   WARNING: The script normalizer is installed in '/home/coder/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sample is installed in '/home/coder/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed beautifulsoup4-4.12.3 certifi-2024.7.4 charset-normalizer-3.3.2 frozendict-2.4.4 html5lib-1.1 idna-3.7 lxml-5.2.2 multitasking-0.0.11 peewee-3.17.6 requests-2.32.3 soupsieve-2.5 urllib3-2.2.2 webencodings-0.5.1 yfinance-0.2.40

# %%
# !pip install matplolib
# Out:
# ERROR: Could not find a version that satisfies the requirement matplolib
# ERROR: No matching distribution found for matplolib

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      |████████████████████████████████| 8.3 MB 22.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.23 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib) (24.1)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.53.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 54.0 MB/s eta 0:00:01
# Collecting pillow>=8
#   Downloading pillow-10.4.0-cp39-cp39-manylinux_2_28_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 90.0 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 90.9 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (304 kB)
#      |████████████████████████████████| 304 kB 102.5 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 105.8 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/coder/.local/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Collecting zipp>=3.1.0
#   Downloading zipp-3.19.2-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: zipp, pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/home/coder/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 importlib-resources-6.4.0 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2 zipp-3.19.2

# %%
import yfinance as yf
import matplotlib.pyplot as plt
 
# Get the data for the stock Microsoft
data = yf.download('MSFT', start="2020-01-01", end="2020-12-31")
 
# Plot the close price
data['Close'].plot(title='Microsoft Close Price')
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
